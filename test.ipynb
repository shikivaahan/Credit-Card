# %%
import pandas as pd

# %%
# Read in the parquet files
df = pd.read_csv(r'C:\Users\User\OneDrive - Imperial College London\Desktop\Documents\GitHub\Credit-Card\data\raw\all_2023q3_2024q1_FULL.csv')
df_auth = pd.read_csv(r'C:\Users\User\OneDrive - Imperial College London\Desktop\Documents\GitHub\Credit-Card\data\raw\authenticated_2023q3_2024q1_FULL.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_28320\3894930168.py:2: DtypeWarning: Columns (3,7,9,11,12,13,14,20,39,47,52,53,54,55,62,70,71,78,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\User\OneDrive - Imperial College London\Desktop\Documents\GitHub\Credit-Card\data\raw\all_2023q3_2024q1_FULL.csv')
# C:\Users\User\AppData\Local\Temp\ipykernel_28320\3894930168.py:3: DtypeWarning: Columns (43,50,52,60,73,74,75) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_auth = pd.read_csv(r'C:\Users\User\OneDrive - Imperial College London\Desktop\Documents\GitHub\Credit-Card\data\raw\authenticated_2023q3_2024q1_FULL.csv')

# %%
print(df.shape)
df.columns
# Out:
# (391604, 94)
# Index(['v', 'id', 'acquiring_bank_name', 'api_version', 'approval_code',
#        'assessment_id', 'authentication_id', 'authorization_additional_data',
#        'authorization_id', 'authorization_receipt_number',
#        'authorization_request_id', 'authorization_request_token',
#        'authorization_response', 'authorization_transaction_date',
#        'authorized_amount', 'avs_code', 'bank_merchant_id',
#        'bank_reconciliation_id', 'business_id', 'callback_url',
#        'capture_amount', 'capture_request_id', 'capture_response',
#        'card_brand', 'card_data_id', 'card_expiration_month',
#        'card_expiration_year', 'card_holder_name', 'card_type', 'cavv',
#        'cc_version', 'charge_type', 'client_id', 'client_type', 'country',
#        'country_code', 'created', 'credit_card_payment_channel',
#        'credit_card_processor', 'credit_card_token', 'credit_card_token_id',
#        'currency', 'cvn_code', 'descriptor', 'eci', 'external_id',
#        'failure_reason', 'fee_amount', 'fee_label', 'original_id',
#        'installment', 'internal_metadata', 'is_blocked_by_fraud',
#        'is_cvn_submitted', 'is_switcher', 'is_t4', 'issuing_bank_name',
#        'masked_card_number', 'merchant_id', 'merchant_reference_code',
#        'metadata', 'mid_label', 'network_token_id', 'order', 'order_id',
#        'payment_processor_response', 'processor_response', 'promotion',
#        'reconciliation_id', 'refund_status', 'requester_email',
#        'retrieval_reference_number', 'reversed_amount', 'rewards',
#        'settlement_date', 'settlement_id', 'settlement_status',
#        'settlement_updated', 'should_authenticate_credit_card',
#        'should_settle_directly', 'status', 'system_trace_audit_number',
#        'total_refund_amount', 'total_refund_fee_amount', 'transaction_channel',
#        'transaction_id', 'ucaf', 'updated', 'use_reward', 'vat_amount',
#        'version', 'xid', 'dt', 'cof_type'],
#       dtype='object')

# %%
print(df_auth.shape)
df_auth.columns
# Out:
# (475066, 77)
# Index(['v', 'id', 'acs_url', 'amount', 'authentication_transaction_id',
#        'authentication_type', 'authentication_verification_response',
#        'authorization_id', 'billing_details', 'business_id', 'card_bank',
#        'card_brand', 'card_data_id', 'card_expiration_month',
#        'card_expiration_year', 'cavv', 'cavv_algorithm', 'cc_version',
#        'client_id', 'client_type', 'commerce_indicator', 'country',
#        'country_code', 'created', 'credit_card_enrollment_info',
#        'credit_card_payment_channel', 'credit_card_token',
#        'credit_card_token_id', 'currency', 'cybersource_merchant_id',
#        'directory_server_transaction_id', 'eci', 'eci_raw', 'external_id',
#        'failure_reason', 'original_id', 'initial_client_type',
#        'initiate_three_ds_url', 'ip_address', 'is_auto_timeout', 'is_enrolled',
#        'language', 'masked_card_number', 'md', 'merchant_name',
#        'merchant_reference_code', 'merchant_url', 'pa_req', 'pares_status',
#        'processor_type', 'proof_xml', 'proxy_pan', 'redirect_html', 'referer',
#        'request_id', 'request_token', 'return_url', 'session_id', 'status',
#        'status_updated', 'term_url', 'three_ds_method_data', 'three_ds_result',
#        'three_ds_version', 'token_creation_date', 'token_type',
#        'ucaf_authentication_data', 'ucaf_collection_indicator', 'updated',
#        'user_agent', 'veres_enrolled', 'x_forwarded_for', 'xid', 'cof_type',
#        'payment_method_id', 'mid_label', 'dt'],
#       dtype='object')

# %%
# Ensure we are dealing with the same data type
df['id'] = df['id'].astype(str)
df_auth['authentication_transaction_id'] = df_auth['authentication_transaction_id'].astype(str)

# Count occurrences
df_counts = df['id'].value_counts()
df_auth_counts = df_auth['authentication_transaction_id'].value_counts()

# Calculate matches
matches_df_to_auth = df_counts[df_counts.index.isin(df_auth_counts.index)]
matches_auth_to_df = df_auth_counts[df_auth_counts.index.isin(df_counts.index)]

# Total counts
total_df = len(df)
total_df_auth = len(df_auth)

# Calculate match rates
match_rate_df_to_auth = (matches_df_to_auth.sum() / total_df) * 100
match_rate_auth_to_df = (matches_auth_to_df.sum() / total_df_auth) * 100

print(f"Match rate from 'df' to 'df_auth': {match_rate_df_to_auth:.2f}%")
print(f"Match rate from 'df_auth' to 'df': {match_rate_auth_to_df:.2f}%")
# Out:
# Match rate from 'df' to 'df_auth': 0.00%
# Match rate from 'df_auth' to 'df': 49.51%

# %%
# Define column names
df_col = 'id'
df_auth_col = 'authentication_transaction_id'

# Calculate the match rate of df[df_col] in df_auth[df_auth_col]
match_rate_df_in_auth = df[df_col].isin(df_auth[df_auth_col]).mean()

# Calculate the match rate of df_auth[df_auth_col] in df[df_col]
match_rate_auth_in_df = df_auth[df_auth_col].isin(df[df_col]).mean()

print(f"Match rate of df.{df_col} in df_auth.{df_auth_col}: {match_rate_df_in_auth:.4f}")
print(f"Match rate of df_auth.{df_auth_col} in df.{df_col}: {match_rate_auth_in_df:.4f}")
# Out:
# Match rate of df.id in df_auth.authentication_transaction_id: 0.0000
# Match rate of df_auth.authentication_transaction_id in df.id: 0.4951

# %%
import itertools
import numpy as np
from operator import itemgetter

# Get all column names ending with 'id' from both DataFrames
df_id_columns = [col for col in df.columns if col.endswith('id')]
df_auth_id_columns = [col for col in df_auth.columns if col.endswith('id')]

# Generate all combinations of columns
all_combinations = list(itertools.product(df_id_columns, df_auth_id_columns))

all_results = []

# Calculate match rates for all combinations
for df_col, df_auth_col in all_combinations:
    # Drop NaN values and reset index to ensure alignment
    df_col_clean = df[df_col].dropna().reset_index(drop=True)
    df_auth_col_clean = df_auth[df_auth_col].dropna().reset_index(drop=True)

    # Convert to sets for better matching
    df_col_set = set(df_col_clean)
    df_auth_col_set = set(df_auth_col_clean)

    # Calculate the match rates
    match_rate_df_in_auth = len(df_col_set & df_auth_col_set) / len(df_col_set) if df_col_set else 0
    match_rate_auth_in_df = len(df_auth_col_set & df_col_set) / len(df_auth_col_set) if df_auth_col_set else 0

    # Calculate NaN percentages
    nan_percent_df = df[df_col].isna().mean() * 100
    nan_percent_df_auth = df_auth[df_auth_col].isna().mean() * 100

    # Store the results
    all_results.append((
        df_col, 
        df_auth_col, 
        match_rate_df_in_auth, 
        match_rate_auth_in_df, 
        max(match_rate_df_in_auth, match_rate_auth_in_df),
        nan_percent_df,
        nan_percent_df_auth
    ))

# Sort results by the maximum match rate in descending order
sorted_results = sorted(all_results, key=itemgetter(4), reverse=True)

# Print the top matches
print("Top matches (in descending order of maximum match rate):")
for result in sorted_results:
    df_col, df_auth_col, rate_df_in_auth, rate_auth_in_df, max_rate, nan_df, nan_df_auth = result
    print(f"\nMatch between df.{df_col} and df_auth.{df_auth_col}:")
    print(f"  Match rate of df.{df_col} in df_auth.{df_auth_col}: {rate_df_in_auth:.4f}")
    print(f"  Match rate of df_auth.{df_auth_col} in df.{df_col}: {rate_auth_in_df:.4f}")
    print(f"  Maximum match rate: {max_rate:.4f}")
    print(f"  NaN percentage in df.{df_col}: {nan_df:.2f}%")
    print(f"  NaN percentage in df_auth.{df_auth_col}: {nan_df_auth:.2f}%")
# Out:
# Top matches (in descending order of maximum match rate):
#
# Match between df.merchant_id and df_auth.cybersource_merchant_id:
#   Match rate of df.merchant_id in df_auth.cybersource_merchant_id: 0.5402
#   Match rate of df_auth.cybersource_merchant_id in df.merchant_id: 0.8832
#   Maximum match rate: 0.8832
#   NaN percentage in df.merchant_id: 0.00%
#   NaN percentage in df_auth.cybersource_merchant_id: 0.00%
#
# Match between df.business_id and df_auth.business_id:
#   Match rate of df.business_id in df_auth.business_id: 0.6616
#   Match rate of df_auth.business_id in df.business_id: 0.6667
#   Maximum match rate: 0.6667
#   NaN percentage in df.business_id: 0.00%
#   NaN percentage in df_auth.business_id: 0.00%
#
# Match between df.bank_merchant_id and df_auth.cybersource_merchant_id:
#   Match rate of df.bank_merchant_id in df_auth.cybersource_merchant_id: 0.3214
#   Match rate of df_auth.cybersource_merchant_id in df.bank_merchant_id: 0.5255
#   Maximum match rate: 0.5255
#   NaN percentage in df.bank_merchant_id: 1.70%
#   NaN percentage in df_auth.cybersource_merchant_id: 0.00%
#
# Match between df.card_data_id and df_auth.card_data_id:
#   Match rate of df.card_data_id in df_auth.card_data_id: 0.0479
#   Match rate of df_auth.card_data_id in df.card_data_id: 0.0439
#   Maximum match rate: 0.0479
#   NaN percentage in df.card_data_id: 2.22%
#   NaN percentage in df_auth.card_data_id: 0.58%
#
# Match between df.credit_card_token_id and df_auth.credit_card_token_id:
#   Match rate of df.credit_card_token_id in df_auth.credit_card_token_id: 0.0129
#   Match rate of df_auth.credit_card_token_id in df.credit_card_token_id: 0.0095
#   Maximum match rate: 0.0129
#   NaN percentage in df.credit_card_token_id: 7.39%
#   NaN percentage in df_auth.credit_card_token_id: 6.39%
#
# Match between df.external_id and df_auth.external_id:
#   Match rate of df.external_id in df_auth.external_id: 0.0000
#   Match rate of df_auth.external_id in df.external_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.external_id: 0.00%
#   NaN percentage in df_auth.external_id: 86.22%
#
# Match between df.id and df_auth.authentication_transaction_id:
#   Match rate of df.id in df_auth.authentication_transaction_id: 0.0000
#   Match rate of df_auth.authentication_transaction_id in df.id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.id: 0.00%
#   NaN percentage in df_auth.authentication_transaction_id: 0.00%
#
# Match between df.id and df_auth.id:
#   Match rate of df.id in df_auth.id: 0.0000
#   Match rate of df_auth.id in df.id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.id: 0.00%
#   NaN percentage in df_auth.id: 0.00%
#
# Match between df.id and df_auth.authorization_id:
#   Match rate of df.id in df_auth.authorization_id: 0.0000
#   Match rate of df_auth.authorization_id in df.id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.id: 0.00%
#   NaN percentage in df_auth.authorization_id: 63.11%
#
# Match between df.id and df_auth.business_id:
#   Match rate of df.id in df_auth.business_id: 0.0000
#   Match rate of df_auth.business_id in df.id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.id: 0.00%
#   NaN percentage in df_auth.business_id: 0.00%
#
# Match between df.id and df_auth.card_data_id:
#   Match rate of df.id in df_auth.card_data_id: 0.0000
#   Match rate of df_auth.card_data_id in df.id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.id: 0.00%
#   NaN percentage in df_auth.card_data_id: 0.58%
#
# Match between df.id and df_auth.client_id:
#   Match rate of df.id in df_auth.client_id: 0.0000
#   Match rate of df_auth.client_id in df.id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.id: 0.00%
#   NaN percentage in df_auth.client_id: 97.76%
#
# Match between df.id and df_auth.credit_card_token_id:
#   Match rate of df.id in df_auth.credit_card_token_id: 0.0000
#   Match rate of df_auth.credit_card_token_id in df.id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.id: 0.00%
#   NaN percentage in df_auth.credit_card_token_id: 6.39%
#
# Match between df.id and df_auth.cybersource_merchant_id:
#   Match rate of df.id in df_auth.cybersource_merchant_id: 0.0000
#   Match rate of df_auth.cybersource_merchant_id in df.id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.id: 0.00%
#   NaN percentage in df_auth.cybersource_merchant_id: 0.00%
#
# Match between df.id and df_auth.directory_server_transaction_id:
#   Match rate of df.id in df_auth.directory_server_transaction_id: 0.0000
#   Match rate of df_auth.directory_server_transaction_id in df.id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.id: 0.00%
#   NaN percentage in df_auth.directory_server_transaction_id: 12.16%
#
# Match between df.id and df_auth.external_id:
#   Match rate of df.id in df_auth.external_id: 0.0000
#   Match rate of df_auth.external_id in df.id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.id: 0.00%
#   NaN percentage in df_auth.external_id: 86.22%
#
# Match between df.id and df_auth.original_id:
#   Match rate of df.id in df_auth.original_id: 0.0000
#   Match rate of df_auth.original_id in df.id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.id: 0.00%
#   NaN percentage in df_auth.original_id: 0.00%
#
# Match between df.id and df_auth.request_id:
#   Match rate of df.id in df_auth.request_id: 0.0000
#   Match rate of df_auth.request_id in df.id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.id: 0.00%
#   NaN percentage in df_auth.request_id: 3.85%
#
# Match between df.id and df_auth.session_id:
#   Match rate of df.id in df_auth.session_id: 0.0000
#   Match rate of df_auth.session_id in df.id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.id: 0.00%
#   NaN percentage in df_auth.session_id: 100.00%
#
# Match between df.id and df_auth.xid:
#   Match rate of df.id in df_auth.xid: 0.0000
#   Match rate of df_auth.xid in df.id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.id: 0.00%
#   NaN percentage in df_auth.xid: 82.47%
#
# Match between df.id and df_auth.payment_method_id:
#   Match rate of df.id in df_auth.payment_method_id: 0.0000
#   Match rate of df_auth.payment_method_id in df.id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.id: 0.00%
#   NaN percentage in df_auth.payment_method_id: 99.24%
#
# Match between df.assessment_id and df_auth.id:
#   Match rate of df.assessment_id in df_auth.id: 0.0000
#   Match rate of df_auth.id in df.assessment_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.assessment_id: 23.41%
#   NaN percentage in df_auth.id: 0.00%
#
# Match between df.assessment_id and df_auth.authentication_transaction_id:
#   Match rate of df.assessment_id in df_auth.authentication_transaction_id: 0.0000
#   Match rate of df_auth.authentication_transaction_id in df.assessment_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.assessment_id: 23.41%
#   NaN percentage in df_auth.authentication_transaction_id: 0.00%
#
# Match between df.assessment_id and df_auth.authorization_id:
#   Match rate of df.assessment_id in df_auth.authorization_id: 0.0000
#   Match rate of df_auth.authorization_id in df.assessment_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.assessment_id: 23.41%
#   NaN percentage in df_auth.authorization_id: 63.11%
#
# Match between df.assessment_id and df_auth.business_id:
#   Match rate of df.assessment_id in df_auth.business_id: 0.0000
#   Match rate of df_auth.business_id in df.assessment_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.assessment_id: 23.41%
#   NaN percentage in df_auth.business_id: 0.00%
#
# Match between df.assessment_id and df_auth.card_data_id:
#   Match rate of df.assessment_id in df_auth.card_data_id: 0.0000
#   Match rate of df_auth.card_data_id in df.assessment_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.assessment_id: 23.41%
#   NaN percentage in df_auth.card_data_id: 0.58%
#
# Match between df.assessment_id and df_auth.client_id:
#   Match rate of df.assessment_id in df_auth.client_id: 0.0000
#   Match rate of df_auth.client_id in df.assessment_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.assessment_id: 23.41%
#   NaN percentage in df_auth.client_id: 97.76%
#
# Match between df.assessment_id and df_auth.credit_card_token_id:
#   Match rate of df.assessment_id in df_auth.credit_card_token_id: 0.0000
#   Match rate of df_auth.credit_card_token_id in df.assessment_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.assessment_id: 23.41%
#   NaN percentage in df_auth.credit_card_token_id: 6.39%
#
# Match between df.assessment_id and df_auth.cybersource_merchant_id:
#   Match rate of df.assessment_id in df_auth.cybersource_merchant_id: 0.0000
#   Match rate of df_auth.cybersource_merchant_id in df.assessment_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.assessment_id: 23.41%
#   NaN percentage in df_auth.cybersource_merchant_id: 0.00%
#
# Match between df.assessment_id and df_auth.directory_server_transaction_id:
#   Match rate of df.assessment_id in df_auth.directory_server_transaction_id: 0.0000
#   Match rate of df_auth.directory_server_transaction_id in df.assessment_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.assessment_id: 23.41%
#   NaN percentage in df_auth.directory_server_transaction_id: 12.16%
#
# Match between df.assessment_id and df_auth.external_id:
#   Match rate of df.assessment_id in df_auth.external_id: 0.0000
#   Match rate of df_auth.external_id in df.assessment_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.assessment_id: 23.41%
#   NaN percentage in df_auth.external_id: 86.22%
#
# Match between df.assessment_id and df_auth.original_id:
#   Match rate of df.assessment_id in df_auth.original_id: 0.0000
#   Match rate of df_auth.original_id in df.assessment_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.assessment_id: 23.41%
#   NaN percentage in df_auth.original_id: 0.00%
#
# Match between df.assessment_id and df_auth.request_id:
#   Match rate of df.assessment_id in df_auth.request_id: 0.0000
#   Match rate of df_auth.request_id in df.assessment_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.assessment_id: 23.41%
#   NaN percentage in df_auth.request_id: 3.85%
#
# Match between df.assessment_id and df_auth.session_id:
#   Match rate of df.assessment_id in df_auth.session_id: 0.0000
#   Match rate of df_auth.session_id in df.assessment_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.assessment_id: 23.41%
#   NaN percentage in df_auth.session_id: 100.00%
#
# Match between df.assessment_id and df_auth.xid:
#   Match rate of df.assessment_id in df_auth.xid: 0.0000
#   Match rate of df_auth.xid in df.assessment_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.assessment_id: 23.41%
#   NaN percentage in df_auth.xid: 82.47%
#
# Match between df.assessment_id and df_auth.payment_method_id:
#   Match rate of df.assessment_id in df_auth.payment_method_id: 0.0000
#   Match rate of df_auth.payment_method_id in df.assessment_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.assessment_id: 23.41%
#   NaN percentage in df_auth.payment_method_id: 99.24%
#
# Match between df.authentication_id and df_auth.id:
#   Match rate of df.authentication_id in df_auth.id: 0.0000
#   Match rate of df_auth.id in df.authentication_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authentication_id: 33.10%
#   NaN percentage in df_auth.id: 0.00%
#
# Match between df.authentication_id and df_auth.authentication_transaction_id:
#   Match rate of df.authentication_id in df_auth.authentication_transaction_id: 0.0000
#   Match rate of df_auth.authentication_transaction_id in df.authentication_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authentication_id: 33.10%
#   NaN percentage in df_auth.authentication_transaction_id: 0.00%
#
# Match between df.authentication_id and df_auth.authorization_id:
#   Match rate of df.authentication_id in df_auth.authorization_id: 0.0000
#   Match rate of df_auth.authorization_id in df.authentication_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authentication_id: 33.10%
#   NaN percentage in df_auth.authorization_id: 63.11%
#
# Match between df.authentication_id and df_auth.business_id:
#   Match rate of df.authentication_id in df_auth.business_id: 0.0000
#   Match rate of df_auth.business_id in df.authentication_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authentication_id: 33.10%
#   NaN percentage in df_auth.business_id: 0.00%
#
# Match between df.authentication_id and df_auth.card_data_id:
#   Match rate of df.authentication_id in df_auth.card_data_id: 0.0000
#   Match rate of df_auth.card_data_id in df.authentication_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authentication_id: 33.10%
#   NaN percentage in df_auth.card_data_id: 0.58%
#
# Match between df.authentication_id and df_auth.client_id:
#   Match rate of df.authentication_id in df_auth.client_id: 0.0000
#   Match rate of df_auth.client_id in df.authentication_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authentication_id: 33.10%
#   NaN percentage in df_auth.client_id: 97.76%
#
# Match between df.authentication_id and df_auth.credit_card_token_id:
#   Match rate of df.authentication_id in df_auth.credit_card_token_id: 0.0000
#   Match rate of df_auth.credit_card_token_id in df.authentication_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authentication_id: 33.10%
#   NaN percentage in df_auth.credit_card_token_id: 6.39%
#
# Match between df.authentication_id and df_auth.cybersource_merchant_id:
#   Match rate of df.authentication_id in df_auth.cybersource_merchant_id: 0.0000
#   Match rate of df_auth.cybersource_merchant_id in df.authentication_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authentication_id: 33.10%
#   NaN percentage in df_auth.cybersource_merchant_id: 0.00%
#
# Match between df.authentication_id and df_auth.directory_server_transaction_id:
#   Match rate of df.authentication_id in df_auth.directory_server_transaction_id: 0.0000
#   Match rate of df_auth.directory_server_transaction_id in df.authentication_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authentication_id: 33.10%
#   NaN percentage in df_auth.directory_server_transaction_id: 12.16%
#
# Match between df.authentication_id and df_auth.external_id:
#   Match rate of df.authentication_id in df_auth.external_id: 0.0000
#   Match rate of df_auth.external_id in df.authentication_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authentication_id: 33.10%
#   NaN percentage in df_auth.external_id: 86.22%
#
# Match between df.authentication_id and df_auth.original_id:
#   Match rate of df.authentication_id in df_auth.original_id: 0.0000
#   Match rate of df_auth.original_id in df.authentication_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authentication_id: 33.10%
#   NaN percentage in df_auth.original_id: 0.00%
#
# Match between df.authentication_id and df_auth.request_id:
#   Match rate of df.authentication_id in df_auth.request_id: 0.0000
#   Match rate of df_auth.request_id in df.authentication_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authentication_id: 33.10%
#   NaN percentage in df_auth.request_id: 3.85%
#
# Match between df.authentication_id and df_auth.session_id:
#   Match rate of df.authentication_id in df_auth.session_id: 0.0000
#   Match rate of df_auth.session_id in df.authentication_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authentication_id: 33.10%
#   NaN percentage in df_auth.session_id: 100.00%
#
# Match between df.authentication_id and df_auth.xid:
#   Match rate of df.authentication_id in df_auth.xid: 0.0000
#   Match rate of df_auth.xid in df.authentication_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authentication_id: 33.10%
#   NaN percentage in df_auth.xid: 82.47%
#
# Match between df.authentication_id and df_auth.payment_method_id:
#   Match rate of df.authentication_id in df_auth.payment_method_id: 0.0000
#   Match rate of df_auth.payment_method_id in df.authentication_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authentication_id: 33.10%
#   NaN percentage in df_auth.payment_method_id: 99.24%
#
# Match between df.authorization_id and df_auth.id:
#   Match rate of df.authorization_id in df_auth.id: 0.0000
#   Match rate of df_auth.id in df.authorization_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_id: 0.00%
#   NaN percentage in df_auth.id: 0.00%
#
# Match between df.authorization_id and df_auth.authentication_transaction_id:
#   Match rate of df.authorization_id in df_auth.authentication_transaction_id: 0.0000
#   Match rate of df_auth.authentication_transaction_id in df.authorization_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_id: 0.00%
#   NaN percentage in df_auth.authentication_transaction_id: 0.00%
#
# Match between df.authorization_id and df_auth.authorization_id:
#   Match rate of df.authorization_id in df_auth.authorization_id: 0.0000
#   Match rate of df_auth.authorization_id in df.authorization_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_id: 0.00%
#   NaN percentage in df_auth.authorization_id: 63.11%
#
# Match between df.authorization_id and df_auth.business_id:
#   Match rate of df.authorization_id in df_auth.business_id: 0.0000
#   Match rate of df_auth.business_id in df.authorization_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_id: 0.00%
#   NaN percentage in df_auth.business_id: 0.00%
#
# Match between df.authorization_id and df_auth.card_data_id:
#   Match rate of df.authorization_id in df_auth.card_data_id: 0.0000
#   Match rate of df_auth.card_data_id in df.authorization_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_id: 0.00%
#   NaN percentage in df_auth.card_data_id: 0.58%
#
# Match between df.authorization_id and df_auth.client_id:
#   Match rate of df.authorization_id in df_auth.client_id: 0.0000
#   Match rate of df_auth.client_id in df.authorization_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_id: 0.00%
#   NaN percentage in df_auth.client_id: 97.76%
#
# Match between df.authorization_id and df_auth.credit_card_token_id:
#   Match rate of df.authorization_id in df_auth.credit_card_token_id: 0.0000
#   Match rate of df_auth.credit_card_token_id in df.authorization_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_id: 0.00%
#   NaN percentage in df_auth.credit_card_token_id: 6.39%
#
# Match between df.authorization_id and df_auth.cybersource_merchant_id:
#   Match rate of df.authorization_id in df_auth.cybersource_merchant_id: 0.0000
#   Match rate of df_auth.cybersource_merchant_id in df.authorization_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_id: 0.00%
#   NaN percentage in df_auth.cybersource_merchant_id: 0.00%
#
# Match between df.authorization_id and df_auth.directory_server_transaction_id:
#   Match rate of df.authorization_id in df_auth.directory_server_transaction_id: 0.0000
#   Match rate of df_auth.directory_server_transaction_id in df.authorization_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_id: 0.00%
#   NaN percentage in df_auth.directory_server_transaction_id: 12.16%
#
# Match between df.authorization_id and df_auth.external_id:
#   Match rate of df.authorization_id in df_auth.external_id: 0.0000
#   Match rate of df_auth.external_id in df.authorization_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_id: 0.00%
#   NaN percentage in df_auth.external_id: 86.22%
#
# Match between df.authorization_id and df_auth.original_id:
#   Match rate of df.authorization_id in df_auth.original_id: 0.0000
#   Match rate of df_auth.original_id in df.authorization_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_id: 0.00%
#   NaN percentage in df_auth.original_id: 0.00%
#
# Match between df.authorization_id and df_auth.request_id:
#   Match rate of df.authorization_id in df_auth.request_id: 0.0000
#   Match rate of df_auth.request_id in df.authorization_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_id: 0.00%
#   NaN percentage in df_auth.request_id: 3.85%
#
# Match between df.authorization_id and df_auth.session_id:
#   Match rate of df.authorization_id in df_auth.session_id: 0.0000
#   Match rate of df_auth.session_id in df.authorization_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_id: 0.00%
#   NaN percentage in df_auth.session_id: 100.00%
#
# Match between df.authorization_id and df_auth.xid:
#   Match rate of df.authorization_id in df_auth.xid: 0.0000
#   Match rate of df_auth.xid in df.authorization_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_id: 0.00%
#   NaN percentage in df_auth.xid: 82.47%
#
# Match between df.authorization_id and df_auth.payment_method_id:
#   Match rate of df.authorization_id in df_auth.payment_method_id: 0.0000
#   Match rate of df_auth.payment_method_id in df.authorization_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_id: 0.00%
#   NaN percentage in df_auth.payment_method_id: 99.24%
#
# Match between df.authorization_request_id and df_auth.id:
#   Match rate of df.authorization_request_id in df_auth.id: 0.0000
#   Match rate of df_auth.id in df.authorization_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_request_id: 22.22%
#   NaN percentage in df_auth.id: 0.00%
#
# Match between df.authorization_request_id and df_auth.authentication_transaction_id:
#   Match rate of df.authorization_request_id in df_auth.authentication_transaction_id: 0.0000
#   Match rate of df_auth.authentication_transaction_id in df.authorization_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_request_id: 22.22%
#   NaN percentage in df_auth.authentication_transaction_id: 0.00%
#
# Match between df.authorization_request_id and df_auth.authorization_id:
#   Match rate of df.authorization_request_id in df_auth.authorization_id: 0.0000
#   Match rate of df_auth.authorization_id in df.authorization_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_request_id: 22.22%
#   NaN percentage in df_auth.authorization_id: 63.11%
#
# Match between df.authorization_request_id and df_auth.business_id:
#   Match rate of df.authorization_request_id in df_auth.business_id: 0.0000
#   Match rate of df_auth.business_id in df.authorization_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_request_id: 22.22%
#   NaN percentage in df_auth.business_id: 0.00%
#
# Match between df.authorization_request_id and df_auth.card_data_id:
#   Match rate of df.authorization_request_id in df_auth.card_data_id: 0.0000
#   Match rate of df_auth.card_data_id in df.authorization_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_request_id: 22.22%
#   NaN percentage in df_auth.card_data_id: 0.58%
#
# Match between df.authorization_request_id and df_auth.client_id:
#   Match rate of df.authorization_request_id in df_auth.client_id: 0.0000
#   Match rate of df_auth.client_id in df.authorization_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_request_id: 22.22%
#   NaN percentage in df_auth.client_id: 97.76%
#
# Match between df.authorization_request_id and df_auth.credit_card_token_id:
#   Match rate of df.authorization_request_id in df_auth.credit_card_token_id: 0.0000
#   Match rate of df_auth.credit_card_token_id in df.authorization_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_request_id: 22.22%
#   NaN percentage in df_auth.credit_card_token_id: 6.39%
#
# Match between df.authorization_request_id and df_auth.cybersource_merchant_id:
#   Match rate of df.authorization_request_id in df_auth.cybersource_merchant_id: 0.0000
#   Match rate of df_auth.cybersource_merchant_id in df.authorization_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_request_id: 22.22%
#   NaN percentage in df_auth.cybersource_merchant_id: 0.00%
#
# Match between df.authorization_request_id and df_auth.directory_server_transaction_id:
#   Match rate of df.authorization_request_id in df_auth.directory_server_transaction_id: 0.0000
#   Match rate of df_auth.directory_server_transaction_id in df.authorization_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_request_id: 22.22%
#   NaN percentage in df_auth.directory_server_transaction_id: 12.16%
#
# Match between df.authorization_request_id and df_auth.external_id:
#   Match rate of df.authorization_request_id in df_auth.external_id: 0.0000
#   Match rate of df_auth.external_id in df.authorization_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_request_id: 22.22%
#   NaN percentage in df_auth.external_id: 86.22%
#
# Match between df.authorization_request_id and df_auth.original_id:
#   Match rate of df.authorization_request_id in df_auth.original_id: 0.0000
#   Match rate of df_auth.original_id in df.authorization_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_request_id: 22.22%
#   NaN percentage in df_auth.original_id: 0.00%
#
# Match between df.authorization_request_id and df_auth.request_id:
#   Match rate of df.authorization_request_id in df_auth.request_id: 0.0000
#   Match rate of df_auth.request_id in df.authorization_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_request_id: 22.22%
#   NaN percentage in df_auth.request_id: 3.85%
#
# Match between df.authorization_request_id and df_auth.session_id:
#   Match rate of df.authorization_request_id in df_auth.session_id: 0.0000
#   Match rate of df_auth.session_id in df.authorization_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_request_id: 22.22%
#   NaN percentage in df_auth.session_id: 100.00%
#
# Match between df.authorization_request_id and df_auth.xid:
#   Match rate of df.authorization_request_id in df_auth.xid: 0.0000
#   Match rate of df_auth.xid in df.authorization_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_request_id: 22.22%
#   NaN percentage in df_auth.xid: 82.47%
#
# Match between df.authorization_request_id and df_auth.payment_method_id:
#   Match rate of df.authorization_request_id in df_auth.payment_method_id: 0.0000
#   Match rate of df_auth.payment_method_id in df.authorization_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.authorization_request_id: 22.22%
#   NaN percentage in df_auth.payment_method_id: 99.24%
#
# Match between df.bank_merchant_id and df_auth.id:
#   Match rate of df.bank_merchant_id in df_auth.id: 0.0000
#   Match rate of df_auth.id in df.bank_merchant_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_merchant_id: 1.70%
#   NaN percentage in df_auth.id: 0.00%
#
# Match between df.bank_merchant_id and df_auth.authentication_transaction_id:
#   Match rate of df.bank_merchant_id in df_auth.authentication_transaction_id: 0.0000
#   Match rate of df_auth.authentication_transaction_id in df.bank_merchant_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_merchant_id: 1.70%
#   NaN percentage in df_auth.authentication_transaction_id: 0.00%
#
# Match between df.bank_merchant_id and df_auth.authorization_id:
#   Match rate of df.bank_merchant_id in df_auth.authorization_id: 0.0000
#   Match rate of df_auth.authorization_id in df.bank_merchant_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_merchant_id: 1.70%
#   NaN percentage in df_auth.authorization_id: 63.11%
#
# Match between df.bank_merchant_id and df_auth.business_id:
#   Match rate of df.bank_merchant_id in df_auth.business_id: 0.0000
#   Match rate of df_auth.business_id in df.bank_merchant_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_merchant_id: 1.70%
#   NaN percentage in df_auth.business_id: 0.00%
#
# Match between df.bank_merchant_id and df_auth.card_data_id:
#   Match rate of df.bank_merchant_id in df_auth.card_data_id: 0.0000
#   Match rate of df_auth.card_data_id in df.bank_merchant_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_merchant_id: 1.70%
#   NaN percentage in df_auth.card_data_id: 0.58%
#
# Match between df.bank_merchant_id and df_auth.client_id:
#   Match rate of df.bank_merchant_id in df_auth.client_id: 0.0000
#   Match rate of df_auth.client_id in df.bank_merchant_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_merchant_id: 1.70%
#   NaN percentage in df_auth.client_id: 97.76%
#
# Match between df.bank_merchant_id and df_auth.credit_card_token_id:
#   Match rate of df.bank_merchant_id in df_auth.credit_card_token_id: 0.0000
#   Match rate of df_auth.credit_card_token_id in df.bank_merchant_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_merchant_id: 1.70%
#   NaN percentage in df_auth.credit_card_token_id: 6.39%
#
# Match between df.bank_merchant_id and df_auth.directory_server_transaction_id:
#   Match rate of df.bank_merchant_id in df_auth.directory_server_transaction_id: 0.0000
#   Match rate of df_auth.directory_server_transaction_id in df.bank_merchant_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_merchant_id: 1.70%
#   NaN percentage in df_auth.directory_server_transaction_id: 12.16%
#
# Match between df.bank_merchant_id and df_auth.external_id:
#   Match rate of df.bank_merchant_id in df_auth.external_id: 0.0000
#   Match rate of df_auth.external_id in df.bank_merchant_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_merchant_id: 1.70%
#   NaN percentage in df_auth.external_id: 86.22%
#
# Match between df.bank_merchant_id and df_auth.original_id:
#   Match rate of df.bank_merchant_id in df_auth.original_id: 0.0000
#   Match rate of df_auth.original_id in df.bank_merchant_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_merchant_id: 1.70%
#   NaN percentage in df_auth.original_id: 0.00%
#
# Match between df.bank_merchant_id and df_auth.request_id:
#   Match rate of df.bank_merchant_id in df_auth.request_id: 0.0000
#   Match rate of df_auth.request_id in df.bank_merchant_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_merchant_id: 1.70%
#   NaN percentage in df_auth.request_id: 3.85%
#
# Match between df.bank_merchant_id and df_auth.session_id:
#   Match rate of df.bank_merchant_id in df_auth.session_id: 0.0000
#   Match rate of df_auth.session_id in df.bank_merchant_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_merchant_id: 1.70%
#   NaN percentage in df_auth.session_id: 100.00%
#
# Match between df.bank_merchant_id and df_auth.xid:
#   Match rate of df.bank_merchant_id in df_auth.xid: 0.0000
#   Match rate of df_auth.xid in df.bank_merchant_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_merchant_id: 1.70%
#   NaN percentage in df_auth.xid: 82.47%
#
# Match between df.bank_merchant_id and df_auth.payment_method_id:
#   Match rate of df.bank_merchant_id in df_auth.payment_method_id: 0.0000
#   Match rate of df_auth.payment_method_id in df.bank_merchant_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_merchant_id: 1.70%
#   NaN percentage in df_auth.payment_method_id: 99.24%
#
# Match between df.bank_reconciliation_id and df_auth.id:
#   Match rate of df.bank_reconciliation_id in df_auth.id: 0.0000
#   Match rate of df_auth.id in df.bank_reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_reconciliation_id: 65.77%
#   NaN percentage in df_auth.id: 0.00%
#
# Match between df.bank_reconciliation_id and df_auth.authentication_transaction_id:
#   Match rate of df.bank_reconciliation_id in df_auth.authentication_transaction_id: 0.0000
#   Match rate of df_auth.authentication_transaction_id in df.bank_reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_reconciliation_id: 65.77%
#   NaN percentage in df_auth.authentication_transaction_id: 0.00%
#
# Match between df.bank_reconciliation_id and df_auth.authorization_id:
#   Match rate of df.bank_reconciliation_id in df_auth.authorization_id: 0.0000
#   Match rate of df_auth.authorization_id in df.bank_reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_reconciliation_id: 65.77%
#   NaN percentage in df_auth.authorization_id: 63.11%
#
# Match between df.bank_reconciliation_id and df_auth.business_id:
#   Match rate of df.bank_reconciliation_id in df_auth.business_id: 0.0000
#   Match rate of df_auth.business_id in df.bank_reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_reconciliation_id: 65.77%
#   NaN percentage in df_auth.business_id: 0.00%
#
# Match between df.bank_reconciliation_id and df_auth.card_data_id:
#   Match rate of df.bank_reconciliation_id in df_auth.card_data_id: 0.0000
#   Match rate of df_auth.card_data_id in df.bank_reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_reconciliation_id: 65.77%
#   NaN percentage in df_auth.card_data_id: 0.58%
#
# Match between df.bank_reconciliation_id and df_auth.client_id:
#   Match rate of df.bank_reconciliation_id in df_auth.client_id: 0.0000
#   Match rate of df_auth.client_id in df.bank_reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_reconciliation_id: 65.77%
#   NaN percentage in df_auth.client_id: 97.76%
#
# Match between df.bank_reconciliation_id and df_auth.credit_card_token_id:
#   Match rate of df.bank_reconciliation_id in df_auth.credit_card_token_id: 0.0000
#   Match rate of df_auth.credit_card_token_id in df.bank_reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_reconciliation_id: 65.77%
#   NaN percentage in df_auth.credit_card_token_id: 6.39%
#
# Match between df.bank_reconciliation_id and df_auth.cybersource_merchant_id:
#   Match rate of df.bank_reconciliation_id in df_auth.cybersource_merchant_id: 0.0000
#   Match rate of df_auth.cybersource_merchant_id in df.bank_reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_reconciliation_id: 65.77%
#   NaN percentage in df_auth.cybersource_merchant_id: 0.00%
#
# Match between df.bank_reconciliation_id and df_auth.directory_server_transaction_id:
#   Match rate of df.bank_reconciliation_id in df_auth.directory_server_transaction_id: 0.0000
#   Match rate of df_auth.directory_server_transaction_id in df.bank_reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_reconciliation_id: 65.77%
#   NaN percentage in df_auth.directory_server_transaction_id: 12.16%
#
# Match between df.bank_reconciliation_id and df_auth.external_id:
#   Match rate of df.bank_reconciliation_id in df_auth.external_id: 0.0000
#   Match rate of df_auth.external_id in df.bank_reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_reconciliation_id: 65.77%
#   NaN percentage in df_auth.external_id: 86.22%
#
# Match between df.bank_reconciliation_id and df_auth.original_id:
#   Match rate of df.bank_reconciliation_id in df_auth.original_id: 0.0000
#   Match rate of df_auth.original_id in df.bank_reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_reconciliation_id: 65.77%
#   NaN percentage in df_auth.original_id: 0.00%
#
# Match between df.bank_reconciliation_id and df_auth.request_id:
#   Match rate of df.bank_reconciliation_id in df_auth.request_id: 0.0000
#   Match rate of df_auth.request_id in df.bank_reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_reconciliation_id: 65.77%
#   NaN percentage in df_auth.request_id: 3.85%
#
# Match between df.bank_reconciliation_id and df_auth.session_id:
#   Match rate of df.bank_reconciliation_id in df_auth.session_id: 0.0000
#   Match rate of df_auth.session_id in df.bank_reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_reconciliation_id: 65.77%
#   NaN percentage in df_auth.session_id: 100.00%
#
# Match between df.bank_reconciliation_id and df_auth.xid:
#   Match rate of df.bank_reconciliation_id in df_auth.xid: 0.0000
#   Match rate of df_auth.xid in df.bank_reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_reconciliation_id: 65.77%
#   NaN percentage in df_auth.xid: 82.47%
#
# Match between df.bank_reconciliation_id and df_auth.payment_method_id:
#   Match rate of df.bank_reconciliation_id in df_auth.payment_method_id: 0.0000
#   Match rate of df_auth.payment_method_id in df.bank_reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.bank_reconciliation_id: 65.77%
#   NaN percentage in df_auth.payment_method_id: 99.24%
#
# Match between df.business_id and df_auth.id:
#   Match rate of df.business_id in df_auth.id: 0.0000
#   Match rate of df_auth.id in df.business_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.business_id: 0.00%
#   NaN percentage in df_auth.id: 0.00%
#
# Match between df.business_id and df_auth.authentication_transaction_id:
#   Match rate of df.business_id in df_auth.authentication_transaction_id: 0.0000
#   Match rate of df_auth.authentication_transaction_id in df.business_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.business_id: 0.00%
#   NaN percentage in df_auth.authentication_transaction_id: 0.00%
#
# Match between df.business_id and df_auth.authorization_id:
#   Match rate of df.business_id in df_auth.authorization_id: 0.0000
#   Match rate of df_auth.authorization_id in df.business_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.business_id: 0.00%
#   NaN percentage in df_auth.authorization_id: 63.11%
#
# Match between df.business_id and df_auth.card_data_id:
#   Match rate of df.business_id in df_auth.card_data_id: 0.0000
#   Match rate of df_auth.card_data_id in df.business_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.business_id: 0.00%
#   NaN percentage in df_auth.card_data_id: 0.58%
#
# Match between df.business_id and df_auth.client_id:
#   Match rate of df.business_id in df_auth.client_id: 0.0000
#   Match rate of df_auth.client_id in df.business_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.business_id: 0.00%
#   NaN percentage in df_auth.client_id: 97.76%
#
# Match between df.business_id and df_auth.credit_card_token_id:
#   Match rate of df.business_id in df_auth.credit_card_token_id: 0.0000
#   Match rate of df_auth.credit_card_token_id in df.business_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.business_id: 0.00%
#   NaN percentage in df_auth.credit_card_token_id: 6.39%
#
# Match between df.business_id and df_auth.cybersource_merchant_id:
#   Match rate of df.business_id in df_auth.cybersource_merchant_id: 0.0000
#   Match rate of df_auth.cybersource_merchant_id in df.business_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.business_id: 0.00%
#   NaN percentage in df_auth.cybersource_merchant_id: 0.00%
#
# Match between df.business_id and df_auth.directory_server_transaction_id:
#   Match rate of df.business_id in df_auth.directory_server_transaction_id: 0.0000
#   Match rate of df_auth.directory_server_transaction_id in df.business_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.business_id: 0.00%
#   NaN percentage in df_auth.directory_server_transaction_id: 12.16%
#
# Match between df.business_id and df_auth.external_id:
#   Match rate of df.business_id in df_auth.external_id: 0.0000
#   Match rate of df_auth.external_id in df.business_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.business_id: 0.00%
#   NaN percentage in df_auth.external_id: 86.22%
#
# Match between df.business_id and df_auth.original_id:
#   Match rate of df.business_id in df_auth.original_id: 0.0000
#   Match rate of df_auth.original_id in df.business_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.business_id: 0.00%
#   NaN percentage in df_auth.original_id: 0.00%
#
# Match between df.business_id and df_auth.request_id:
#   Match rate of df.business_id in df_auth.request_id: 0.0000
#   Match rate of df_auth.request_id in df.business_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.business_id: 0.00%
#   NaN percentage in df_auth.request_id: 3.85%
#
# Match between df.business_id and df_auth.session_id:
#   Match rate of df.business_id in df_auth.session_id: 0.0000
#   Match rate of df_auth.session_id in df.business_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.business_id: 0.00%
#   NaN percentage in df_auth.session_id: 100.00%
#
# Match between df.business_id and df_auth.xid:
#   Match rate of df.business_id in df_auth.xid: 0.0000
#   Match rate of df_auth.xid in df.business_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.business_id: 0.00%
#   NaN percentage in df_auth.xid: 82.47%
#
# Match between df.business_id and df_auth.payment_method_id:
#   Match rate of df.business_id in df_auth.payment_method_id: 0.0000
#   Match rate of df_auth.payment_method_id in df.business_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.business_id: 0.00%
#   NaN percentage in df_auth.payment_method_id: 99.24%
#
# Match between df.capture_request_id and df_auth.id:
#   Match rate of df.capture_request_id in df_auth.id: 0.0000
#   Match rate of df_auth.id in df.capture_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.capture_request_id: 37.94%
#   NaN percentage in df_auth.id: 0.00%
#
# Match between df.capture_request_id and df_auth.authentication_transaction_id:
#   Match rate of df.capture_request_id in df_auth.authentication_transaction_id: 0.0000
#   Match rate of df_auth.authentication_transaction_id in df.capture_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.capture_request_id: 37.94%
#   NaN percentage in df_auth.authentication_transaction_id: 0.00%
#
# Match between df.capture_request_id and df_auth.authorization_id:
#   Match rate of df.capture_request_id in df_auth.authorization_id: 0.0000
#   Match rate of df_auth.authorization_id in df.capture_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.capture_request_id: 37.94%
#   NaN percentage in df_auth.authorization_id: 63.11%
#
# Match between df.capture_request_id and df_auth.business_id:
#   Match rate of df.capture_request_id in df_auth.business_id: 0.0000
#   Match rate of df_auth.business_id in df.capture_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.capture_request_id: 37.94%
#   NaN percentage in df_auth.business_id: 0.00%
#
# Match between df.capture_request_id and df_auth.card_data_id:
#   Match rate of df.capture_request_id in df_auth.card_data_id: 0.0000
#   Match rate of df_auth.card_data_id in df.capture_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.capture_request_id: 37.94%
#   NaN percentage in df_auth.card_data_id: 0.58%
#
# Match between df.capture_request_id and df_auth.client_id:
#   Match rate of df.capture_request_id in df_auth.client_id: 0.0000
#   Match rate of df_auth.client_id in df.capture_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.capture_request_id: 37.94%
#   NaN percentage in df_auth.client_id: 97.76%
#
# Match between df.capture_request_id and df_auth.credit_card_token_id:
#   Match rate of df.capture_request_id in df_auth.credit_card_token_id: 0.0000
#   Match rate of df_auth.credit_card_token_id in df.capture_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.capture_request_id: 37.94%
#   NaN percentage in df_auth.credit_card_token_id: 6.39%
#
# Match between df.capture_request_id and df_auth.cybersource_merchant_id:
#   Match rate of df.capture_request_id in df_auth.cybersource_merchant_id: 0.0000
#   Match rate of df_auth.cybersource_merchant_id in df.capture_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.capture_request_id: 37.94%
#   NaN percentage in df_auth.cybersource_merchant_id: 0.00%
#
# Match between df.capture_request_id and df_auth.directory_server_transaction_id:
#   Match rate of df.capture_request_id in df_auth.directory_server_transaction_id: 0.0000
#   Match rate of df_auth.directory_server_transaction_id in df.capture_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.capture_request_id: 37.94%
#   NaN percentage in df_auth.directory_server_transaction_id: 12.16%
#
# Match between df.capture_request_id and df_auth.external_id:
#   Match rate of df.capture_request_id in df_auth.external_id: 0.0000
#   Match rate of df_auth.external_id in df.capture_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.capture_request_id: 37.94%
#   NaN percentage in df_auth.external_id: 86.22%
#
# Match between df.capture_request_id and df_auth.original_id:
#   Match rate of df.capture_request_id in df_auth.original_id: 0.0000
#   Match rate of df_auth.original_id in df.capture_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.capture_request_id: 37.94%
#   NaN percentage in df_auth.original_id: 0.00%
#
# Match between df.capture_request_id and df_auth.request_id:
#   Match rate of df.capture_request_id in df_auth.request_id: 0.0000
#   Match rate of df_auth.request_id in df.capture_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.capture_request_id: 37.94%
#   NaN percentage in df_auth.request_id: 3.85%
#
# Match between df.capture_request_id and df_auth.session_id:
#   Match rate of df.capture_request_id in df_auth.session_id: 0.0000
#   Match rate of df_auth.session_id in df.capture_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.capture_request_id: 37.94%
#   NaN percentage in df_auth.session_id: 100.00%
#
# Match between df.capture_request_id and df_auth.xid:
#   Match rate of df.capture_request_id in df_auth.xid: 0.0000
#   Match rate of df_auth.xid in df.capture_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.capture_request_id: 37.94%
#   NaN percentage in df_auth.xid: 82.47%
#
# Match between df.capture_request_id and df_auth.payment_method_id:
#   Match rate of df.capture_request_id in df_auth.payment_method_id: 0.0000
#   Match rate of df_auth.payment_method_id in df.capture_request_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.capture_request_id: 37.94%
#   NaN percentage in df_auth.payment_method_id: 99.24%
#
# Match between df.card_data_id and df_auth.id:
#   Match rate of df.card_data_id in df_auth.id: 0.0000
#   Match rate of df_auth.id in df.card_data_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.card_data_id: 2.22%
#   NaN percentage in df_auth.id: 0.00%
#
# Match between df.card_data_id and df_auth.authentication_transaction_id:
#   Match rate of df.card_data_id in df_auth.authentication_transaction_id: 0.0000
#   Match rate of df_auth.authentication_transaction_id in df.card_data_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.card_data_id: 2.22%
#   NaN percentage in df_auth.authentication_transaction_id: 0.00%
#
# Match between df.card_data_id and df_auth.authorization_id:
#   Match rate of df.card_data_id in df_auth.authorization_id: 0.0000
#   Match rate of df_auth.authorization_id in df.card_data_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.card_data_id: 2.22%
#   NaN percentage in df_auth.authorization_id: 63.11%
#
# Match between df.card_data_id and df_auth.business_id:
#   Match rate of df.card_data_id in df_auth.business_id: 0.0000
#   Match rate of df_auth.business_id in df.card_data_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.card_data_id: 2.22%
#   NaN percentage in df_auth.business_id: 0.00%
#
# Match between df.card_data_id and df_auth.client_id:
#   Match rate of df.card_data_id in df_auth.client_id: 0.0000
#   Match rate of df_auth.client_id in df.card_data_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.card_data_id: 2.22%
#   NaN percentage in df_auth.client_id: 97.76%
#
# Match between df.card_data_id and df_auth.credit_card_token_id:
#   Match rate of df.card_data_id in df_auth.credit_card_token_id: 0.0000
#   Match rate of df_auth.credit_card_token_id in df.card_data_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.card_data_id: 2.22%
#   NaN percentage in df_auth.credit_card_token_id: 6.39%
#
# Match between df.card_data_id and df_auth.cybersource_merchant_id:
#   Match rate of df.card_data_id in df_auth.cybersource_merchant_id: 0.0000
#   Match rate of df_auth.cybersource_merchant_id in df.card_data_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.card_data_id: 2.22%
# ...
#   Maximum match rate: 0.0000
#   NaN percentage in df.reconciliation_id: 100.00%
#   NaN percentage in df_auth.directory_server_transaction_id: 12.16%
#
# Match between df.reconciliation_id and df_auth.external_id:
#   Match rate of df.reconciliation_id in df_auth.external_id: 0.0000
#   Match rate of df_auth.external_id in df.reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.reconciliation_id: 100.00%
#   NaN percentage in df_auth.external_id: 86.22%
#
# Match between df.reconciliation_id and df_auth.original_id:
#   Match rate of df.reconciliation_id in df_auth.original_id: 0.0000
#   Match rate of df_auth.original_id in df.reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.reconciliation_id: 100.00%
#   NaN percentage in df_auth.original_id: 0.00%
#
# Match between df.reconciliation_id and df_auth.request_id:
#   Match rate of df.reconciliation_id in df_auth.request_id: 0.0000
#   Match rate of df_auth.request_id in df.reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.reconciliation_id: 100.00%
#   NaN percentage in df_auth.request_id: 3.85%
#
# Match between df.reconciliation_id and df_auth.session_id:
#   Match rate of df.reconciliation_id in df_auth.session_id: 0.0000
#   Match rate of df_auth.session_id in df.reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.reconciliation_id: 100.00%
#   NaN percentage in df_auth.session_id: 100.00%
#
# Match between df.reconciliation_id and df_auth.xid:
#   Match rate of df.reconciliation_id in df_auth.xid: 0.0000
#   Match rate of df_auth.xid in df.reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.reconciliation_id: 100.00%
#   NaN percentage in df_auth.xid: 82.47%
#
# Match between df.reconciliation_id and df_auth.payment_method_id:
#   Match rate of df.reconciliation_id in df_auth.payment_method_id: 0.0000
#   Match rate of df_auth.payment_method_id in df.reconciliation_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.reconciliation_id: 100.00%
#   NaN percentage in df_auth.payment_method_id: 99.24%
#
# Match between df.settlement_id and df_auth.id:
#   Match rate of df.settlement_id in df_auth.id: 0.0000
#   Match rate of df_auth.id in df.settlement_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.settlement_id: 100.00%
#   NaN percentage in df_auth.id: 0.00%
#
# Match between df.settlement_id and df_auth.authentication_transaction_id:
#   Match rate of df.settlement_id in df_auth.authentication_transaction_id: 0.0000
#   Match rate of df_auth.authentication_transaction_id in df.settlement_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.settlement_id: 100.00%
#   NaN percentage in df_auth.authentication_transaction_id: 0.00%
#
# Match between df.settlement_id and df_auth.authorization_id:
#   Match rate of df.settlement_id in df_auth.authorization_id: 0.0000
#   Match rate of df_auth.authorization_id in df.settlement_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.settlement_id: 100.00%
#   NaN percentage in df_auth.authorization_id: 63.11%
#
# Match between df.settlement_id and df_auth.business_id:
#   Match rate of df.settlement_id in df_auth.business_id: 0.0000
#   Match rate of df_auth.business_id in df.settlement_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.settlement_id: 100.00%
#   NaN percentage in df_auth.business_id: 0.00%
#
# Match between df.settlement_id and df_auth.card_data_id:
#   Match rate of df.settlement_id in df_auth.card_data_id: 0.0000
#   Match rate of df_auth.card_data_id in df.settlement_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.settlement_id: 100.00%
#   NaN percentage in df_auth.card_data_id: 0.58%
#
# Match between df.settlement_id and df_auth.client_id:
#   Match rate of df.settlement_id in df_auth.client_id: 0.0000
#   Match rate of df_auth.client_id in df.settlement_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.settlement_id: 100.00%
#   NaN percentage in df_auth.client_id: 97.76%
#
# Match between df.settlement_id and df_auth.credit_card_token_id:
#   Match rate of df.settlement_id in df_auth.credit_card_token_id: 0.0000
#   Match rate of df_auth.credit_card_token_id in df.settlement_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.settlement_id: 100.00%
#   NaN percentage in df_auth.credit_card_token_id: 6.39%
#
# Match between df.settlement_id and df_auth.cybersource_merchant_id:
#   Match rate of df.settlement_id in df_auth.cybersource_merchant_id: 0.0000
#   Match rate of df_auth.cybersource_merchant_id in df.settlement_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.settlement_id: 100.00%
#   NaN percentage in df_auth.cybersource_merchant_id: 0.00%
#
# Match between df.settlement_id and df_auth.directory_server_transaction_id:
#   Match rate of df.settlement_id in df_auth.directory_server_transaction_id: 0.0000
#   Match rate of df_auth.directory_server_transaction_id in df.settlement_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.settlement_id: 100.00%
#   NaN percentage in df_auth.directory_server_transaction_id: 12.16%
#
# Match between df.settlement_id and df_auth.external_id:
#   Match rate of df.settlement_id in df_auth.external_id: 0.0000
#   Match rate of df_auth.external_id in df.settlement_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.settlement_id: 100.00%
#   NaN percentage in df_auth.external_id: 86.22%
#
# Match between df.settlement_id and df_auth.original_id:
#   Match rate of df.settlement_id in df_auth.original_id: 0.0000
#   Match rate of df_auth.original_id in df.settlement_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.settlement_id: 100.00%
#   NaN percentage in df_auth.original_id: 0.00%
#
# Match between df.settlement_id and df_auth.request_id:
#   Match rate of df.settlement_id in df_auth.request_id: 0.0000
#   Match rate of df_auth.request_id in df.settlement_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.settlement_id: 100.00%
#   NaN percentage in df_auth.request_id: 3.85%
#
# Match between df.settlement_id and df_auth.session_id:
#   Match rate of df.settlement_id in df_auth.session_id: 0.0000
#   Match rate of df_auth.session_id in df.settlement_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.settlement_id: 100.00%
#   NaN percentage in df_auth.session_id: 100.00%
#
# Match between df.settlement_id and df_auth.xid:
#   Match rate of df.settlement_id in df_auth.xid: 0.0000
#   Match rate of df_auth.xid in df.settlement_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.settlement_id: 100.00%
#   NaN percentage in df_auth.xid: 82.47%
#
# Match between df.settlement_id and df_auth.payment_method_id:
#   Match rate of df.settlement_id in df_auth.payment_method_id: 0.0000
#   Match rate of df_auth.payment_method_id in df.settlement_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.settlement_id: 100.00%
#   NaN percentage in df_auth.payment_method_id: 99.24%
#
# Match between df.transaction_id and df_auth.id:
#   Match rate of df.transaction_id in df_auth.id: 0.0000
#   Match rate of df_auth.id in df.transaction_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.transaction_id: 36.23%
#   NaN percentage in df_auth.id: 0.00%
#
# Match between df.transaction_id and df_auth.authentication_transaction_id:
#   Match rate of df.transaction_id in df_auth.authentication_transaction_id: 0.0000
#   Match rate of df_auth.authentication_transaction_id in df.transaction_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.transaction_id: 36.23%
#   NaN percentage in df_auth.authentication_transaction_id: 0.00%
#
# Match between df.transaction_id and df_auth.authorization_id:
#   Match rate of df.transaction_id in df_auth.authorization_id: 0.0000
#   Match rate of df_auth.authorization_id in df.transaction_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.transaction_id: 36.23%
#   NaN percentage in df_auth.authorization_id: 63.11%
#
# Match between df.transaction_id and df_auth.business_id:
#   Match rate of df.transaction_id in df_auth.business_id: 0.0000
#   Match rate of df_auth.business_id in df.transaction_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.transaction_id: 36.23%
#   NaN percentage in df_auth.business_id: 0.00%
#
# Match between df.transaction_id and df_auth.card_data_id:
#   Match rate of df.transaction_id in df_auth.card_data_id: 0.0000
#   Match rate of df_auth.card_data_id in df.transaction_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.transaction_id: 36.23%
#   NaN percentage in df_auth.card_data_id: 0.58%
#
# Match between df.transaction_id and df_auth.client_id:
#   Match rate of df.transaction_id in df_auth.client_id: 0.0000
#   Match rate of df_auth.client_id in df.transaction_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.transaction_id: 36.23%
#   NaN percentage in df_auth.client_id: 97.76%
#
# Match between df.transaction_id and df_auth.credit_card_token_id:
#   Match rate of df.transaction_id in df_auth.credit_card_token_id: 0.0000
#   Match rate of df_auth.credit_card_token_id in df.transaction_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.transaction_id: 36.23%
#   NaN percentage in df_auth.credit_card_token_id: 6.39%
#
# Match between df.transaction_id and df_auth.cybersource_merchant_id:
#   Match rate of df.transaction_id in df_auth.cybersource_merchant_id: 0.0000
#   Match rate of df_auth.cybersource_merchant_id in df.transaction_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.transaction_id: 36.23%
#   NaN percentage in df_auth.cybersource_merchant_id: 0.00%
#
# Match between df.transaction_id and df_auth.directory_server_transaction_id:
#   Match rate of df.transaction_id in df_auth.directory_server_transaction_id: 0.0000
#   Match rate of df_auth.directory_server_transaction_id in df.transaction_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.transaction_id: 36.23%
#   NaN percentage in df_auth.directory_server_transaction_id: 12.16%
#
# Match between df.transaction_id and df_auth.external_id:
#   Match rate of df.transaction_id in df_auth.external_id: 0.0000
#   Match rate of df_auth.external_id in df.transaction_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.transaction_id: 36.23%
#   NaN percentage in df_auth.external_id: 86.22%
#
# Match between df.transaction_id and df_auth.original_id:
#   Match rate of df.transaction_id in df_auth.original_id: 0.0000
#   Match rate of df_auth.original_id in df.transaction_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.transaction_id: 36.23%
#   NaN percentage in df_auth.original_id: 0.00%
#
# Match between df.transaction_id and df_auth.request_id:
#   Match rate of df.transaction_id in df_auth.request_id: 0.0000
#   Match rate of df_auth.request_id in df.transaction_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.transaction_id: 36.23%
#   NaN percentage in df_auth.request_id: 3.85%
#
# Match between df.transaction_id and df_auth.session_id:
#   Match rate of df.transaction_id in df_auth.session_id: 0.0000
#   Match rate of df_auth.session_id in df.transaction_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.transaction_id: 36.23%
#   NaN percentage in df_auth.session_id: 100.00%
#
# Match between df.transaction_id and df_auth.xid:
#   Match rate of df.transaction_id in df_auth.xid: 0.0000
#   Match rate of df_auth.xid in df.transaction_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.transaction_id: 36.23%
#   NaN percentage in df_auth.xid: 82.47%
#
# Match between df.transaction_id and df_auth.payment_method_id:
#   Match rate of df.transaction_id in df_auth.payment_method_id: 0.0000
#   Match rate of df_auth.payment_method_id in df.transaction_id: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.transaction_id: 36.23%
#   NaN percentage in df_auth.payment_method_id: 99.24%
#
# Match between df.xid and df_auth.id:
#   Match rate of df.xid in df_auth.id: 0.0000
#   Match rate of df_auth.id in df.xid: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.xid: 80.42%
#   NaN percentage in df_auth.id: 0.00%
#
# Match between df.xid and df_auth.authentication_transaction_id:
#   Match rate of df.xid in df_auth.authentication_transaction_id: 0.0000
#   Match rate of df_auth.authentication_transaction_id in df.xid: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.xid: 80.42%
#   NaN percentage in df_auth.authentication_transaction_id: 0.00%
#
# Match between df.xid and df_auth.authorization_id:
#   Match rate of df.xid in df_auth.authorization_id: 0.0000
#   Match rate of df_auth.authorization_id in df.xid: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.xid: 80.42%
#   NaN percentage in df_auth.authorization_id: 63.11%
#
# Match between df.xid and df_auth.business_id:
#   Match rate of df.xid in df_auth.business_id: 0.0000
#   Match rate of df_auth.business_id in df.xid: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.xid: 80.42%
#   NaN percentage in df_auth.business_id: 0.00%
#
# Match between df.xid and df_auth.card_data_id:
#   Match rate of df.xid in df_auth.card_data_id: 0.0000
#   Match rate of df_auth.card_data_id in df.xid: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.xid: 80.42%
#   NaN percentage in df_auth.card_data_id: 0.58%
#
# Match between df.xid and df_auth.client_id:
#   Match rate of df.xid in df_auth.client_id: 0.0000
#   Match rate of df_auth.client_id in df.xid: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.xid: 80.42%
#   NaN percentage in df_auth.client_id: 97.76%
#
# Match between df.xid and df_auth.credit_card_token_id:
#   Match rate of df.xid in df_auth.credit_card_token_id: 0.0000
#   Match rate of df_auth.credit_card_token_id in df.xid: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.xid: 80.42%
#   NaN percentage in df_auth.credit_card_token_id: 6.39%
#
# Match between df.xid and df_auth.cybersource_merchant_id:
#   Match rate of df.xid in df_auth.cybersource_merchant_id: 0.0000
#   Match rate of df_auth.cybersource_merchant_id in df.xid: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.xid: 80.42%
#   NaN percentage in df_auth.cybersource_merchant_id: 0.00%
#
# Match between df.xid and df_auth.directory_server_transaction_id:
#   Match rate of df.xid in df_auth.directory_server_transaction_id: 0.0000
#   Match rate of df_auth.directory_server_transaction_id in df.xid: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.xid: 80.42%
#   NaN percentage in df_auth.directory_server_transaction_id: 12.16%
#
# Match between df.xid and df_auth.external_id:
#   Match rate of df.xid in df_auth.external_id: 0.0000
#   Match rate of df_auth.external_id in df.xid: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.xid: 80.42%
#   NaN percentage in df_auth.external_id: 86.22%
#
# Match between df.xid and df_auth.original_id:
#   Match rate of df.xid in df_auth.original_id: 0.0000
#   Match rate of df_auth.original_id in df.xid: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.xid: 80.42%
#   NaN percentage in df_auth.original_id: 0.00%
#
# Match between df.xid and df_auth.request_id:
#   Match rate of df.xid in df_auth.request_id: 0.0000
#   Match rate of df_auth.request_id in df.xid: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.xid: 80.42%
#   NaN percentage in df_auth.request_id: 3.85%
#
# Match between df.xid and df_auth.session_id:
#   Match rate of df.xid in df_auth.session_id: 0.0000
#   Match rate of df_auth.session_id in df.xid: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.xid: 80.42%
#   NaN percentage in df_auth.session_id: 100.00%
#
# Match between df.xid and df_auth.xid:
#   Match rate of df.xid in df_auth.xid: 0.0000
#   Match rate of df_auth.xid in df.xid: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.xid: 80.42%
#   NaN percentage in df_auth.xid: 82.47%
#
# Match between df.xid and df_auth.payment_method_id:
#   Match rate of df.xid in df_auth.payment_method_id: 0.0000
#   Match rate of df_auth.payment_method_id in df.xid: 0.0000
#   Maximum match rate: 0.0000
#   NaN percentage in df.xid: 80.42%
#   NaN percentage in df_auth.payment_method_id: 99.24%

# %%
# # Drop NaN values from both columns
df_cleaned = df.dropna(subset=['authentication_id'])
df_auth_cleaned = df_auth.dropna(subset=['id'])

# Check for matching values
matching_values = df_cleaned['authentication_id'].isin(df_auth_cleaned['id'])

# Count the number of matching values
num_matching_values = matching_values.sum()

print(f"Number of matching values: {num_matching_values}")
# Out:
# Number of matching values: 0
