# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\User\OneDrive - Imperial College London\Desktop\Documents\GitHub\Credit-Card\clean__credit_card_production.creditcardcharges.xlsx')
df_auth = pd.read_excel(r'C:\Users\User\OneDrive - Imperial College London\Desktop\Documents\GitHub\Credit-Card\clean__credit_card_production.authenticatedcreditcardtokens.xlsx')

# %%
pd.set_option('display.max_columns', None)

print(df_auth.head(3))
# Out:
#     v                        id  \
# 0 NaN  66c358b20a26be001708f5af
# 1 NaN  66c358b30a26be001708f5b2
# 2 NaN  66c358b715c5b3001676abbf
#
#                                              acs_url     amount  \
# 0  https://3dsecure.bri.co.id/IMS2BRIIDACS/api/3d...  1000000.0
# 1  https://authentication.cardinalcommerce.com/Th...     1999.0
# 2  https://3dsecure.klikbca.com/IMS2BCAIDACS/api/...    33300.0
#
#   authentication_transaction_id authentication_type  \
# 0          qmV4MoXLlbE2oy2RMUi1             BUNDLED
# 1                           NaN             BUNDLED
# 2                           NaN                 PAN
#
#                 authentication_verification_response authorization_id  \
# 0                                                NaN              NaN
# 1  {"eci_raw":"05","failure_reason":null,"veres_e...              NaN
# 2  {"eci_raw":"02","failure_reason":null,"veres_e...              NaN
#
#                                      billing_details  \
# ...

# %%
df.columns
# Out:
# Index(['v', 'id', 'acquiring_bank_name', 'api_version', 'approval_code',
#        'assessment_id', 'authentication_id', 'authorization_additional_data',
#        'authorization_id', 'authorization_receipt_number',
#        'authorization_request_id', 'authorization_request_token',
#        'authorization_response', 'authorization_transaction_date',
#        'authorized_amount', 'avs_code', 'bank_merchant_id',
#        'bank_reconciliation_id', 'business_id', 'callback_url',
#        'capture_amount', 'capture_request_id', 'capture_response',
#        'card_brand', 'card_data_id', 'card_expiration_month',
#        'card_expiration_year', 'card_holder_name', 'card_type', 'cavv',
#        'cc_version', 'charge_type', 'client_id', 'client_type', 'country',
#        'country_code', 'created', 'credit_card_payment_channel',
#        'credit_card_processor', 'credit_card_token', 'credit_card_token_id',
#        'currency', 'cvn_code', 'descriptor', 'eci', 'external_id',
# ...
